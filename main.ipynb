# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2022_02_08-02_30_31_AM.csv')

# %%
data
# Out:
#                                           uuid price_string price_string_unf  \
# 0         638744a4-b0ae-4166-8cb6-5c063c862036          NaN              NaN
# 1         ab313969-02cc-48b2-9daf-0054efb70b92          NaN              NaN
# 2         acbd66ff-79f8-467a-91f9-108a45af5626       $19.95              NaN
# 3         963915d6-b2e3-4098-b242-9410593cf205       $92.00              NaN
# 4         b5b68f3c-b1e0-40e5-8ee5-e2f7236c1daf        11.50              NaN
# ...                                        ...          ...              ...
# 13729995  2a13338e-9268-4f7b-9e7c-b8c41c72971b          NaN              NaN
# 13729996  fcaedae7-dc20-4da1-b4ae-77368c973088       $69.99              NaN
# 13729997  679f073a-862a-4e43-b5ce-41e45afd3bfa          NaN              NaN
# 13729998  25677eee-c26b-4abf-bd10-ca77a800ba26          NaN              NaN
# 13729999  0f4550de-1f33-48b5-a5ef-fc5e39df208e       $55.00              NaN
#
# ...

# %% [markdown]
# # Task 1

# %% [markdown]
# ## Product Without Prices

# %%
null_price = data[data.price_string.isna()]
null_price
# Out:
#                                           uuid price_string price_string_unf  \
# 0         638744a4-b0ae-4166-8cb6-5c063c862036          NaN              NaN
# 1         ab313969-02cc-48b2-9daf-0054efb70b92          NaN              NaN
# 5         389d9f75-cc3f-4bd2-94f7-93e381a3bed5          NaN              NaN
# 13        1f2766ec-0a27-43f8-b28b-77a44492ead1          NaN              NaN
# 16        7bad39f5-74b9-4611-afb9-46fb135190cd          NaN              NaN
# ...                                        ...          ...              ...
# 13729992  8d763911-79b7-402d-8964-6bfe89692c66          NaN              NaN
# 13729993  2dc182aa-d591-49e4-85d1-5c4a60a09664          NaN              NaN
# 13729995  2a13338e-9268-4f7b-9e7c-b8c41c72971b          NaN              NaN
# 13729997  679f073a-862a-4e43-b5ce-41e45afd3bfa          NaN              NaN
# 13729998  25677eee-c26b-4abf-bd10-ca77a800ba26          NaN              NaN
#
# ...

# %%
print(f'Number of Rows with no Price: {null_price.shape[0]}')
print(f'Number of unique products that have no price: {len(null_price.uuid.unique())}')
# Out:
# Number of Rows with no Price: 8220000
# Number of unique products that have no price: 822

# %%
null_price.groupby('product_type')['uuid'].nunique()
# Out:
# product_type
# Q0FUIExJVFRFUg                             3
# Q29mZmVlIEJlYW5z                           5
# Q29mZmVlIEZpbHRlcnM                        1
# Q29uZGl0aW9uZXIgSGFpcg                     2
# Q29va2llcw                                 3
#                                           ..
# cGV0IEJsYW5rZXQ                            1
# cGV0IFN0YWluIGFuZCBvZG9yIGVsaW1pbmF0b3I    1
# d29tZW5zIE91dGVyd2Vhcg                     2
# d29tZW5zIFdhbGxldA                         1
# d29tZW5zIHN3ZWF0ZXJz                       9
# Name: uuid, Length: 278, dtype: int64

# %% [markdown]
# ## TASK 2

# %% [markdown]
# ### Count based on Product Type (Without Prices)

# %%
count_product_type = null_price.groupby('product_type')['uuid'].nunique()
df_count_product_type = pd.DataFrame(data=count_product_type.values, index = count_product_type.index, columns=['Count'])
df_count_product_type
# Out:
#                                          Count
# product_type
# Q0FUIExJVFRFUg                               3
# Q29mZmVlIEJlYW5z                             5
# Q29mZmVlIEZpbHRlcnM                          1
# Q29uZGl0aW9uZXIgSGFpcg                       2
# Q29va2llcw                                   3
# ...                                        ...
# cGV0IEJsYW5rZXQ                              1
# cGV0IFN0YWluIGFuZCBvZG9yIGVsaW1pbmF0b3I      1
# d29tZW5zIE91dGVyd2Vhcg                       2
# d29tZW5zIFdhbGxldA                           1
# d29tZW5zIHN3ZWF0ZXJz                         9
#
# [278 rows x 1 columns]

# %%
plt.rcParams["figure.figsize"] = [25, 14]
bar_plot = sns.barplot(x = count_product_type.index, y = count_product_type.values)
plt.title('Count Of Different Products Based on Product Type(Without Price)', fontsize=40)

plt.xticks(rotation = 90)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# ### Count based on Category (Without Prices)

# %%
count_category = null_price.groupby('category')['uuid'].nunique()
df_count_category = pd.DataFrame(data = count_category.values, index=count_category.index, columns=['Count'])
df_count_category
# Out:
#                                      Count
# category
# Q2xvdGhpbmcgYW5kIEFjY2Vzc29yaWVz       205
# QXJ0IHN1cHBsaWVz                        13
# QmFieWNhcmU                             57
# RWxlY3Ryb25pY3M                         21
# SG91c2Vob2xkIGFuZCBDbGVhbmluZw          87
# SGVhbHRo                                70
# VG95cyBhbmQgR2FtZXM                     60
# VG9vbHMgYW5kIGhvbWUgaW1wcm92ZW1lbnQ     32
# YmVhdXR5IGFuZCBwZXJzb25hbCBjYXJl        72
# Z3JvY2VyaWVz                           113
# a2l0Y2hpbmcgYW5kIGRpbmluZw              25
# b2ZmaWNlIHByb2R1Y3Rz                     8
# cGV0IHN1cHBsaWVz                        58

# %%
plt.rcParams["figure.figsize"] = [25, 14]
sns.barplot(x = count_category.index, y = count_category.values)
plt.title('Count Of Different Products Based on Category(Without Price)', fontsize=40)

plt.xticks(rotation = 90, fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# ### Count based on Level 1 (Without Prices)

# %%
count_level_1 = null_price.groupby('level_1')['uuid'].nunique()
df_count_level_1 = pd.DataFrame(data=count_level_1.values, index=count_level_1.index, columns=['Count'])
df_count_level_1
# Out:
#                                  Count
# level_1
# MjAgUGludHM                          2
# MzAtIDM1IFBpbnRz                     1
# NTAgUGludHM                          2
# Q0FUIExJVFRFUg                       3
# Q290dG9uIFBhZHM                      2
# ...                                ...
# d29tZW5zIFNhbmRhbHMvU2xpcCBvbnM      2
# d29tZW5zIFdhbGxldA                   1
# d29tZW5zIGJvb3Rz                     2
# eW9nYSBCbG9ja3M                      1
# eW9nYSBib2xzdGVycw                   1
#
# [476 rows x 1 columns]

# %%
plt.rcParams["figure.figsize"] = [25, 14]
sns.barplot(x = count_level_1.index, y = count_level_1.values)
plt.title('Count Of Different Products Based on Level 1(Without Price)', fontsize=40)
plt.xticks(rotation = 90)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# ## Product With Prices

# %%
products_with_price = data[data.price_string.notna()]
print(f'The number of rows containing prices are {products_with_price.shape[0]}')
print(f'The number of unique product containing prices are {products_with_price.uuid.unique().shape[0]}')
# Out:
# The number of rows containing prices are 5510000
# The number of unique product containing prices are 551

# %% [markdown]
# ### Count based on Product Type(With Price)

# %%
count_product_type = products_with_price.groupby('product_type')['uuid'].nunique()
df_count_product_type = pd.DataFrame(data = count_product_type.values, index=count_product_type.index,columns=['Count'])
df_count_product_type
# Out:
#                           Count
# product_type
# Q29mZmVlIEJlYW5z              3
# Q29uZGl0aW9uZXIgSGFpcg        1
# Q29va2luZyBPaWw               7
# Q29va2luZyBVdGVuc2lscw       11
# Q2FuZGxlcy9GcmFnbmFuY2Vz      4
# ...                         ...
# cGV0IEJlZC9NYXR0cmVzc2Vz      1
# cGV0IEJsYW5rZXQ               1
# d29tZW5zIE91dGVyd2Vhcg       13
# d29tZW5zIFdhbGxldA            2
# d29tZW5zIHN3ZWF0ZXJz          3
#
# [209 rows x 1 columns]

# %%
plt.rcParams["figure.figsize"] = [25, 14]
sns.barplot(x = count_product_type.index, y = count_product_type.values)
plt.title('Count Of Different Products Based on Product Type(With Price)', fontsize=40)
plt.xticks(rotation = 90)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# ### Count based on Category(With Price)

# %%
count_category = products_with_price.groupby('category')['uuid'].nunique()
df_count_category = pd.DataFrame(data = count_category.values, index=count_category.index, columns=['Count'])
df_count_category
# Out:
#                                      Count
# category
# Q2xvdGhpbmcgYW5kIEFjY2Vzc29yaWVz       186
# QXJ0IHN1cHBsaWVz                        19
# QmFieWNhcmU                              9
# RWxlY3Ryb25pY3M                         11
# SG91c2Vob2xkIGFuZCBDbGVhbmluZw          70
# SGVhbHRo                                29
# VG95cyBhbmQgR2FtZXM                     19
# VG9vbHMgYW5kIGhvbWUgaW1wcm92ZW1lbnQ     20
# YmVhdXR5IGFuZCBwZXJzb25hbCBjYXJl        75
# Z3JvY2VyaWVz                            48
# a2l0Y2hpbmcgYW5kIGRpbmluZw              34
# b2ZmaWNlIHByb2R1Y3Rz                    15
# cGV0IHN1cHBsaWVz                        16

# %%
plt.rcParams["figure.figsize"] = [25, 14]
sns.barplot(x = count_category.index, y = count_category.values)
plt.title('Count Of Different Products Based on Category(With Price)', fontsize=40)
plt.xticks(rotation = 90, fontsize=18)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# ### Count based on Level 1(With Price)

# %%
count_level_1 = products_with_price.groupby('level_1')['uuid'].nunique()
df_count_level_1 = pd.DataFrame(data = count_level_1.values, index=count_level_1.index, columns=['Count'])
df_count_level_1
# Out:
#                     Count
# level_1
# MTAgQ3Vw                1
# MjAgQ3Vw                1
# MjAgUGludHM             1
# MzAgQ3Vw                1
# MzAtIDM1IFBpbnRz        1
# ...                   ...
# d29tZW5zIGJvb3Rz        2
# d29tZW5zIGhlZWxz        1
# eW9nYSBCbG9ja3M         2
# eW9nYSBib2xzdGVycw      1
# eW9nYSBzdHJhcHM         3
#
# [366 rows x 1 columns]

# %%
plt.rcParams["figure.figsize"] = [25, 14]
sns.barplot(x = count_level_1.index, y = count_level_1.values)
plt.title('Count Of Different Products Based on Level 1(With Price)', fontsize=40)
plt.xticks(rotation = 90)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# ## TASK 3

# %% [markdown]
# #### Here I created a new DataFrame which is copy of the orignal DataFrame to fill the Nan Values of the price_string column in order to implement my conditional algorithms

# %%
df_new = data.copy()
df_new.fillna(-1, inplace=True)

# %% [markdown]
# #### Here i have added a new Column in the DataFrame which contains a boolean depicting whether the value of the price_string needs to be edited or not , if the value is Nan then False if the first character is dollar than False else the value is True

# %%
data.loc[(df_new.price_string !=  -1) | (df_new.price_string.str[0] != '$'), ['have_to_change']] = True
data.loc[(df_new.price_string ==  -1) | (df_new.price_string.str[0] == '$'), ['have_to_change']] = False

# %% [markdown]
# #### Here I have added the dollar sign in front of those values where have_to_change column which is created above conatins true

# %%
data.loc[(data.have_to_change == True), ['price_string']] = '$' + data[data.have_to_change == True].price_string.astype(str)

# %% [markdown]
# #### Here i have removed our have_to_change column

# %%
data.drop(['have_to_change'], axis = 1, inplace=True)

# %% [markdown]
# #### Here i have added two more column conatining value and currency as asked

# %%
data.loc[(df_new.price_string != -1), ['currency']] = data[df_new.price_string != -1].price_string.str[0]
data.loc[(df_new.price_string != -1), ['value']] = data[df_new.price_string != -1].price_string.str[1:]

# %% [markdown]
# #### Here i changed the data type of the value column from str to float

# %%
data.loc[(df_new.price_string != -1), ['value']] = data[df_new.price_string != -1].value.astype(float)

# %%
data
# Out:
#                                           uuid price_string price_string_unf  \
# 0         638744a4-b0ae-4166-8cb6-5c063c862036          NaN              NaN
# 1         ab313969-02cc-48b2-9daf-0054efb70b92          NaN              NaN
# 2         acbd66ff-79f8-467a-91f9-108a45af5626       $19.95              NaN
# 3         963915d6-b2e3-4098-b242-9410593cf205       $92.00              NaN
# 4         b5b68f3c-b1e0-40e5-8ee5-e2f7236c1daf       $11.50              NaN
# ...                                        ...          ...              ...
# 13729995  2a13338e-9268-4f7b-9e7c-b8c41c72971b          NaN              NaN
# 13729996  fcaedae7-dc20-4da1-b4ae-77368c973088       $69.99              NaN
# 13729997  679f073a-862a-4e43-b5ce-41e45afd3bfa          NaN              NaN
# 13729998  25677eee-c26b-4abf-bd10-ca77a800ba26          NaN              NaN
# 13729999  0f4550de-1f33-48b5-a5ef-fc5e39df208e       $55.00              NaN
#
# ...

# %% [markdown]
# ## TASK 4

# %% [markdown]
# #### Here i firstly grouped the data by category and then by applying aggregate function i added a column containing the mean of the value column related to that specific category

# %%
average_price_by_category = data.groupby('category').agg({'value': [np.mean]})
average_price_by_category
# Out:
#                                           value
#                                            mean
# category
# Q2xvdGhpbmcgYW5kIEFjY2Vzc29yaWVz     125.413871
# QXJ0IHN1cHBsaWVz                      19.471053
# QmFieWNhcmU                          163.688889
# RWxlY3Ryb25pY3M                       60.258182
# SG91c2Vob2xkIGFuZCBDbGVhbmluZw        76.199000
# SGVhbHRo                              32.557586
# VG95cyBhbmQgR2FtZXM                   32.448947
# VG9vbHMgYW5kIGhvbWUgaW1wcm92ZW1lbnQ   82.223500
# YmVhdXR5IGFuZCBwZXJzb25hbCBjYXJl      34.745067
# Z3JvY2VyaWVz                          10.541667
# a2l0Y2hpbmcgYW5kIGRpbmluZw            16.703235
# b2ZmaWNlIHByb2R1Y3Rz                  20.480000
# cGV0IHN1cHBsaWVz                      14.181875
